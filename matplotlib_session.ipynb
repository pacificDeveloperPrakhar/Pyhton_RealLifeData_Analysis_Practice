# %%
import matplotlib.pyplot as plt

# %%
plt.plot([12,13,14,15,16,90],[23,24,25,26,28,31])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
v0 = 20  # Initial velocity (m/s)
theta = np.radians(45)  # Launch angle in radians
g = 9.81  # Acceleration due to gravity (m/s^2)

# Time of flight
t_flight = 2 * v0 * np.sin(theta) / g
t = np.linspace(0, t_flight, num=500)

# Equations of motion
x = v0 * np.cos(theta) * t
y = v0 * np.sin(theta) * t - 0.5 * g * t**2

# Plotting
plt.plot(x, y)
plt.title('Projectile Motion')
plt.xlabel=('Horizontal Distance (m)')
plt.ylabel=('Vertical Distance (m)')
plt.grid(True)

# %%
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
#to plot without the line
# you can use o * and . to dpecify which symbol to use for the marker
plt.plot([1,2,3],[7,8,9],'o')

# %%
plt.plot([x for x in range(100)],[y for y in range(100)],'.')

# %%
# you can alos specify the color line and marker type it goes something like this marker\line\color
# visit the w3school to know more 
plt.plot([x for x in range(100)],[y for y in range(100)],".--b")

# %%
from matplotlib import pyplot as plt
plt.scatter([x for x in range(10)],[y for y in range(10)])

# %%
# plotting multiple points or plots in the same graph
plt.plot([2,4,5,6,9,10],[12,15,19,21,13,12],color="#FFC0CB")
plt.plot([1,19,11,10,44,23],[12,23,12,11,32,12],color="#00FF00")

# %%
# to plot multiple figure in the same plane
plt.subplot(1,2,1)
plt.plot([12,13,14,15],[12,13,14,29],color="pink")
plt.subplot(1,2,2)
plt.plot([12,13,14,15],[12,20,14,29],color="green")

# %%
plt.bar(["Apple","Banana"],[20,120] ,width=0.4)
# Out:
# <BarContainer object of 2 artists>

# %%
# to plot with bars going horizontally u should use barh rather than bar funtion
# for instance 

plt.barh(["Apple","Orange","Guava"],[200,120,400])
# Out:
# <BarContainer object of 3 artists>

# %%
# with custom color
plt.barh(["Pencil","Paper","Eraser","Stopper"],[1200,200,300,3000],color="#2fceeb")
# Out:
# <BarContainer object of 4 artists>

# %%
# with width parameter
plt.barh([x for x in range(10)],[y for y in range(1,100,10)])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar([12,3,14],[200,300,500],width=2)
# Out:
# <BarContainer object of 3 artists>

# %%
# for the horizontal bars instead of giving the width parameter we are required to give the height parameter
# likt this
plt.barh([x for x in range(10)],[y for y in range(1,100,10)],height=0.4)
# Out:
# <BarContainer object of 10 artists>
